# %%
import goes_toolkit as gtk

# %%
gtk.baixar_imagem_goes("B06", "2026-06-01T14:00:00Z/2026-06-01T15:00:00Z")
# Out:
# Conectando à STAC API: https://data.inpe.br/bdc/stac/v1/
# Buscando dados para a coleção 'GOES19-L2-CMI-1'...
# Total de registros encontrados: 15
#
# Processando Item ID: GOES19_L2_ABI_202606011500 (Data: 2026-06-01 15:00:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch06/2026/06/S10161306_202606011500.nc
# Salvando em: dados_goes\GOES19_L2_ABI_202606011500_B06.nc...
# Download concluído com sucesso: GOES19_L2_ABI_202606011500_B06.nc
#
# Processando Item ID: GOES19_L2_ABI_202606011450 (Data: 2026-06-01 14:50:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch06/2026/06/S10161306_202606011450.nc
# Salvando em: dados_goes\GOES19_L2_ABI_202606011450_B06.nc...
# Download concluído com sucesso: GOES19_L2_ABI_202606011450_B06.nc
#
# Processando Item ID: GOES19_L2_ABI_202606011440 (Data: 2026-06-01 14:40:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch06/2026/06/S10161306_202606011440.nc
# ...
