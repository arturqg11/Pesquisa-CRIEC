# %%
import goes_toolkit as gtk

# %%
gtk.baixar_roi_goes("B08", "2026-06-01T14:00:00Z/2026-06-01T15:00:00Z", png=True)
# Out:
# Conectando à STAC API: https://data.inpe.br/bdc/stac/v1/
# Buscando dados para a coleção 'GOES19-L2-CMI-1'...
# Total de registros encontrados: 15
#
# Processando Item ID: GOES19_L2_ABI_202606011500 (Data: 2026-06-01 15:00:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch08/2026/06/S10161308_202606011500.nc
# Salvando em: c:\Users\artur\Desktop\Pesquisa-CRIEC\Automações\dados_goes_roi\temp_downloads\GOES19_L2_ABI_202606011500_B08.nc...
# Download concluído com sucesso: GOES19_L2_ABI_202606011500_B08.nc
#
# Processando Item ID: GOES19_L2_ABI_202606011450 (Data: 2026-06-01 14:50:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch08/2026/06/S10161308_202606011450.nc
# Salvando em: c:\Users\artur\Desktop\Pesquisa-CRIEC\Automações\dados_goes_roi\temp_downloads\GOES19_L2_ABI_202606011450_B08.nc...
# Download concluído com sucesso: GOES19_L2_ABI_202606011450_B08.nc
#
# ...
