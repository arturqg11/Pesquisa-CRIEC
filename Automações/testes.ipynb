# %%
import goes_toolkit as gtk

# %%
gtk.roi_mbanda("2026-06-01T14:00:00Z")
# Out:
# Conectando à STAC API: https://data.inpe.br/bdc/stac/v1/
# Buscando dados para a coleção 'GOES19-L2-CMI-1'...
# Total de registros encontrados: 4
#
# Processando Item ID: GOES19_L2_ABI_202606011400 (Data: 2026-06-01 14:00:00+00:00)
# Baixando de: https://data.inpe.br/bdc/data/GOES19-L2-CMI/ch01/2026/06/S10161301_202606011400.nc
# Salvando em: c:\Users\artur\Desktop\Pesquisa-CRIEC\Automações\dados_goes_roi\B01\temp_downloads\GOES19_L2_ABI_202606011400_B01.nc...
# Download concluído com sucesso: GOES19_L2_ABI_202606011400_B01.nc
# Arquivos reportados pelo download: ['c:\\Users\\artur\\Desktop\\Pesquisa-CRIEC\\Automações\\dados_goes_roi\\B01\\temp_downloads\\GOES19_L2_ABI_202606011400_B01.nc']
#
# Recortando o arquivo: GOES19_L2_ABI_202606011400_B01.nc
# c:\Users\artur\Desktop\Pesquisa-CRIEC\Automações\goes_toolkit.py:396: SerializationWarning: saving variable y with floating point data as an integer dtype without any _FillValue to use for NaNs
#   arquivos = baixar_roi_goes(
# ...
